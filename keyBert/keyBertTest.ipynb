# %% [markdown]
# Import the dataset

# %%
import pickle

# File path
file_path = "../Dataset/scifi_reviews_df.pkl"

with open(file_path, 'rb') as file:
    scifi_reviews_df = pickle.load(file)

print("Loaded dataset:", scifi_reviews_df)
# Out:
# Loaded dataset:    Review_ID   Movie_ID        Movie_Title  Rating       Review_Date  \
# 0    9958904  tt0046213  Project Moon Base    10.0    17 August 2024
# 1    3433093  tt0046213  Project Moon Base     NaN     17 March 2016
# 2    7294962  tt0046213  Project Moon Base     8.0  1 September 2021
# 3    4182974  tt0046213  Project Moon Base     2.0       29 May 2018
# 4    9777141  tt0046213  Project Moon Base     6.0        7 May 2024
# ..       ...        ...                ...     ...               ...
# 27   5994043  tt9812258              G-Loc     3.0    14 August 2020
# 28   5982124  tt9812258              G-Loc     7.0    11 August 2020
# 29   6064971  tt9812258              G-Loc     3.0  5 September 2020
# 30   6243718  tt9812258              G-Loc     1.0   7 November 2020
# 31   5982834  tt9812258              G-Loc     4.0    11 August 2020
#
#                                          Review_Title  \
# 0   Donna Martell is 110° in the shade on earth or...
# 1   Large dose of 50's Sci-Fi with their Charming ...
# 2   HIGHLY UNDERRATED...ROBERT HEINLEIN INFLUENCE ...
# 3   If this looked that bad on my small screen, I ...
# 4                       PROJECT MOON-PIE IN YOUR EYE!
# ..                                                ...
# 27  why? why does the stick man hologram have a fa...
# 28                              Good story Low budget
# 29                                           Horrible
# 30             Felt like it was a bad 70s UK TV Movie
# 31                                       Budget SC FI
#
#                                           Review_Text  Helpful_Votes  \
# 0   Donna Martell is 110° in the shade on earth or...              2
# 1   *Spoiler/plot- Project Moon Base, 1953. Among ...              2
# 2   When Viewed Today this Surprising Movie Unsurp...              5
# 3   I got to see this in a double bill with "Desti...              1
# 4   Ahhhh the wonderful 1950 SCI FI films.! Yes th...              1
# ..                                                ...            ...
# 27  ..... does not bode well for the remaining hou...              8
# 28  The script is solid, the CGI decent, acting is...             20
# 29  Was looking for a good space movie...the first...              6
# 30  I got bored. I had to fast forward to the end,...              3
# 31  Fair acting, Cheap sets. Could have been a dec...             11
#
#     Total_Votes
# 0             3
# 1             4
# 2             5
# 3             6
# 4             2
# ..          ...
# 27           21
# 28           24
# 29           14
# 30           10
# 31           18
#
# [4222 rows x 9 columns]

# %%
import subprocess
import sys

# List of required packages
required_packages = [
    "tf-keras", "numpy", "keybert"
]

def install_package(package):
    """Installs a package using pip if it's not already installed."""
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Check and install missing packages
for package in required_packages:
    install_package(package)
# Out:
# Installing tf-keras...
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tf-keras in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tf-keras) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.68.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.7.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.12.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.37.0)
# Requirement already satisfied: rich in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (13.9.4)
# Requirement already satisfied: namex in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.18.0)
# Requirement already satisfied: zipp>=3.20 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.2)
# numpy is already installed.
# keybert is already installed.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from keybert import KeyBERT
from tqdm import tqdm

specific_film = scifi_reviews_df.loc[scifi_reviews_df['Movie_ID'] == 'tt0046213']
kw_model = KeyBERT()
topics = dict()

for index, row in tqdm(specific_film.iterrows(), total=specific_film.shape[0]):
    specific_text = row['Review_Text']
    keywords = kw_model.extract_keywords(specific_text, keyphrase_ngram_range=(1, 3), stop_words='english', top_n=5)
    topics[row['Review_ID']] = keywords
# Out:
# 100%|██████████| 44/44 [00:40<00:00,  1.09it/s]

# %%
topics
# Out:
# {'9958904': [('earth moon film', 0.5195),
#   ('moon movie', 0.5175),
#   ('moon film', 0.5058),
#   ('moon film unusual', 0.4589),
#   ('moon base female', 0.4436)],
#  '3433093': [('women moon filmed', 0.6203),
#   ('women moon', 0.5548),
#   ('mission moon 1972', 0.5292),
#   ('manned mission moon', 0.5206),
#   ('cat women moon', 0.4989)],
#  '7294962': [('spy movie', 0.5409),
#   ('spy movie cold', 0.5329),
#   ('ingredients spy movie', 0.5259),
#   ('surprising movie unsurprisingly', 0.4794),
#   ('movies silly incompetently', 0.4588)],
#  '4182974': [('astronauts rest cast', 0.5316),
#   ('jeanie ironically astronauts', 0.5036),
#   ('destination moon', 0.501),
#   ('ironically astronauts', 0.4707),
#   ('astronauts', 0.4675)],
#  '9777141': [('rocket love movie', 0.5061),
#   ('sci fi films', 0.4942),
#   ('1950 sci fi', 0.4813),
#   ('corny watch astronauts', 0.4607),
#   ('movie remember 1953', 0.4569)],
#  '2952739': [('understand project moon', 0.6195),
#   ('project moon base', 0.5584),
#   ('project moon', 0.5527),
#   ('notice project moon', 0.5344),
#   ('moon base', 0.5024)],
#  '1525320': [('portrayal bad guys', 0.6066),
#   ('worst bunch portrayal', 0.5005),
#   ('badness hayden', 0.496),
#   ('portrayal bad', 0.4717),
#   ('bad guys bland', 0.4664)],
#  '1917986': [('film space station', 0.5485),
#   ('retrospect bad film', 0.5133),
#   ('idea odd film', 0.4858),
#   ('film lovers heinlein', 0.4839),
#   ('film space', 0.4803)],
#  '2561483': [('space ranger', 0.4589),
#   ('soul cast excellent', 0.4503),
#   ('space ranger boasts', 0.4346),
#   ('cast excellent hayden', 0.4244),
#   ('film early 60', 0.4095)],
#  '1805188': [('1953 certainly amusing', 0.5882),
#   ('interesting reveals 1950', 0.4305),
#   ('seriously released 1953', 0.4104),
#   ('science theater 3000', 0.4014),
#   ('science fiction expected', 0.3833)],
#  '7233619': [('heinlein starship troopers', 0.5526),
#   ('robert heinlein starship', 0.5269),
#   ('project moon', 0.5258),
#   ('heinlein starship', 0.5131),
#   ('originally planned pilot', 0.5)],
#  '3045942': [('story according heinlein', 0.5554),
#   ('wrote script heinlein', 0.549),
#   ('gave heinlein credit', 0.5453),
#   ('heinlein given credit', 0.539),
#   ('script heinlein given', 0.5291)],
#  '3479089': [('watch going moon', 0.4597),
#   ('movie dull really', 0.4516),
#   ('movies lot memorable', 0.4511),
#   ('classic trip moon', 0.4501),
#   ('movie dull', 0.4225)],
#  '2413712': [('female astronaut movie', 0.6153),
#   ('astronaut movie worth', 0.5503),
#   ('moon movie', 0.5148),
#   ('astronaut movie', 0.4949),
#   ('land moon movie', 0.4863)],
#  '8364472': [('sabotage project moon', 0.6217),
#   ('moon space station', 0.6131),
#   ('project moon', 0.5172),
#   ('moon music', 0.5125),
#   ('station constructed lunar', 0.508)],
#  '1748032': [('heinlein treats goofy', 0.5303),
#   ('moon send folks', 0.449),
#   ('rousing spacey', 0.4354),
#   ('treats goofy premise', 0.4291),
#   ('robert heinlein', 0.4219)],
#  '9564053': [('sabotage station', 0.4661),
#   ('danger adventure', 0.4415),
#   ('space station', 0.4282),
#   ('space station used', 0.4256),
#   ('military station opposed', 0.4174)],
#  '2604253': [('space station spy', 0.6029),
#   ('problems russian spies', 0.5384),
#   ('russian spies', 0.5336),
#   ('station spy', 0.5294),
#   ('russian spies isn', 0.5127)],
#  '1050615': [('movie insanely sexist', 0.586),
#   ('level sexism film', 0.5304),
#   ('sexist mainstream movies', 0.5218),
#   ('sexism film', 0.5148),
#   ('features female commanding', 0.4802)],
#  '3598293': [('bond film', 0.7166),
#   ('film like bond', 0.7154),
#   ('james bond film', 0.7105),
#   ('bond film space', 0.6663),
#   ('right bond film', 0.6637)],
#  '1003583': [('moonbase pilot planned', 0.6872),
#   ('project moonbase pilot', 0.6486),
#   ('bases moon expedition', 0.633),
#   ('moonbase pilot', 0.6322),
#   ('base known moonbase', 0.6085)],
#  '3013020': [('charming science fiction', 0.5069),
#   ('science fiction film', 0.5019),
#   ('sci fi trip', 0.4706),
#   ('space odyssey', 0.4654),
#   ('little sci fi', 0.4559)],
#  '5048948': [('moon base women', 0.694),
#   ('project moon base', 0.5228),
#   ('moon base', 0.5163),
#   ('bases moon', 0.5129),
#   ('project moon', 0.5112)],
#  '0049985': [('moonbase according movie', 0.487),
#   ('sexist overtones film', 0.458),
#   ('woman land moon', 0.4364),
#   ('acting ability sexist', 0.3776),
#   ('moore marry supposed', 0.3747)],
#  '3222303': [('moon movie slightly', 0.5623),
#   ('moon movie', 0.5536),
#   ('explorers moon movie', 0.5264),
#   ('moon women', 0.5077),
#   ('concerning explorers moon', 0.4966)],
#  '3554388': [('climax special effects', 0.4593),
#   ('derring climax special', 0.45),
#   ('derring climax', 0.4311),
#   ('unexpected minor delight', 0.4172),
#   ('climax special', 0.4091)],
#  '1892798': [('moon enemy freedom', 0.5894),
#   ('moon enemy', 0.5079),
#   ('project moonbase', 0.4982),
#   ('traveling moon enemy', 0.4936),
#   ('moonbase', 0.4683)],
#  '3401619': [('destination moon movie', 0.5261),
#   ('moon pilot', 0.5078),
#   ('ring moon pilot', 0.5035),
#   ('story destination moon', 0.4976),
#   ('pilot film', 0.4693)],
#  '3730346': [('dr wernher duplicate', 0.5452),
#   ('pilot colonel briteis', 0.4991),
#   ('wernher duplicate', 0.4837),
#   ('pilot colonel', 0.456),
#   ('original pilot named', 0.4435)],
#  '2253477': [('project moon', 0.5795),
#   ('project moon base', 0.5576),
#   ('moon base 1953', 0.5411),
#   ('space station moon', 0.5322),
#   ('destination moon', 0.5249)],
#  '1851399': [('luna space flight', 0.4691),
#   ('luna space', 0.4376),
#   ('circum luna space', 0.4173),
#   ('agent sneaks', 0.3952),
#   ('enemy agent sneaks', 0.3684)],
#  '0049984': [('films project moon', 0.5458),
#   ('early fifties shows', 0.528),
#   ('fifties shows like', 0.512),
#   ('moon explains films', 0.5012),
#   ('film early fifties', 0.4987)],
#  '5221040': [('officer moon', 0.5052),
#   ('space scenes cast', 0.4749),
#   ('scenes involving astronaut', 0.469),
#   ('exploratory mission moon', 0.4597),
#   ('space scenes', 0.4593)],
#  '8717977': [('space movies crew', 0.5215),
#   ('station moon thing', 0.4872),
#   ('station moon', 0.4845),
#   ('space movies', 0.4718),
#   ('earth crew', 0.4553)],
#  '0049982': [('year 2000 movies', 0.4482),
#   ('2000 movies look', 0.4438),
#   ('movies moral wonder', 0.4375),
#   ('destination moon silly', 0.4363),
#   ('movies moral', 0.4325)],
#  '1985184': [('moon base sexist', 0.6723),
#   ('women moon thought', 0.5426),
#   ('movie sexist', 0.5318),
#   ('movie sexist argue', 0.5175),
#   ('women movie sexist', 0.5152)],
#  '6673065': [('suspense foreign baddies', 0.4959),
#   ('evil ridiculous moon', 0.4356),
#   ('movie looks', 0.4233),
#   ('like director talmadge', 0.4225),
#   ('imdb advice', 0.4098)],
#  '1412999': [('film stranded moon', 0.5758),
#   ('aliens film', 0.5308),
#   ('aliens film concerns', 0.5274),
#   ('movie 1950s involved', 0.5038),
#   ('sci fi movie', 0.5011)],
#  '5592827': [('hardcore sci fans', 0.4423),
#   ('sci fans', 0.4187),
#   ('story 63 minute', 0.4009),
#   ('movie earth', 0.3987),
#   ('mediocre lots plot', 0.3597)],
#  '9576697': [('woman moon', 0.5938),
#   ('women moon released', 0.5926),
#   ('women moon', 0.5924),
#   ('cat women moon', 0.5883),
#   ('cat woman moon', 0.5829)],
#  '6557139': [('film campy 1950', 0.5562),
#   ('enjoyed film campy', 0.5162),
#   ('campy 1950 dialogue', 0.4908),
#   ('film campy', 0.4897),
#   ('campy 1950', 0.4634)],
#  '4145529': [('women moon 1953', 0.5002),
#   ('cat women moon', 0.4961),
#   ('movie cat women', 0.4941),
#   ('presidency movie cat', 0.4742),
#   ('women moon', 0.4727)],
#  '5612946': [('project moon', 0.5381),
#   ('ring moon 1970', 0.5249),
#   ('moon 1970 mission', 0.513),
#   ('moon 1970', 0.5077),
#   ('mission sent moon', 0.4959)],
#  '2669516': [('sexes theme heinlein', 0.5109),
#   ('space movie historically', 0.5),
#   ('equality sexes theme', 0.4712),
#   ('early space movie', 0.4698),
#   ('sexes theme', 0.4674)]}
