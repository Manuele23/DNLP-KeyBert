# %% [markdown]
# # AI-Generated Review Summaries: Keyword Extraction and Integration

# %% [markdown]
# This notebook focuses on the analysis of a dictionary containing AI-generated summaries derived from user reviews of various films (not all the films). Each entry includes a general summary and detailed reflections on specific aspects such as cinematography, direction, character development, and other thematic dimensions.
#
# The objective is to extract relevant keywords from these textual summaries. Since the content is rooted in audience reviews, the extracted keywords are particularly valuable for capturing subjective interpretations and reception patterns.
#
# The most significant keywords will be identified and integrated into the existing file `keywords_ground_truth.pkl`. This file currently includes keywords primarily based on plot-level information. By appending review-based keywords, the keyword set is enriched with descriptors that better reflect audience perspectives, thereby improving the comprehensiveness and relevance of the feature set.
#
# > **Note**: IA Summaries for *Star Wars: Episode I – The Phantom Menace*, *Star Wars: Episode II – Attack of the Clones*, and *La La Land* are currently missing from the dataset.

# %% [markdown]
# ## Setup: Installing and Importing Required Libraries

# %%
import subprocess
import sys

# List of required packages
required_packages = [
    "pandas", "pickle", "keybert", "sentence-transformers", "tqdm"
]

def install_package(package):
    """Installs a package using pip if it's not already installed."""
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Check and install missing packages
for package in required_packages:
    install_package(package)
# Out:
# pandas is already installed.
# pickle is already installed.
# keybert is already installed.
# Installing sentence-transformers...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentence-transformers in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.46.3)
# Requirement already satisfied: tqdm in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.67.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# tqdm is already installed.

# %%
import pandas as pd
import pickle
from keybert import KeyBERT
from tqdm import tqdm

# %% [markdown]
# ## Load the dictionary with the IA-generated summary

# %% [markdown]
# This cell loads the dictionary of AI-generated summaries from the file `summary_IA.pkl`. Each entry in the dictionary corresponds to a film and contains both a general summary and a set of thematic evaluations. The total number of films with available summaries is displayed to verify successful loading.

# %%
# Load the dictionary containing AI-generated summaries
with open("../Dataset/summary_IA.pkl", "rb") as f:
    all_summaries = pickle.load(f)

# Check how many films are included
print(f"Loaded summaries for {len(all_summaries)} films.")
# Out:
# Loaded summaries for 12 films.

# %% [markdown]
# ## Keyword Extraction from AI-Generated Summaries Using KeyBERT

# %% [markdown]
# This cell performs automatic keyword extraction from the AI-generated summaries using the KeyBERT library.
#
# For each film in the dataset, all thematic sections (e.g., cinematography, character development) are processed individually. If the associated text is non-empty, KeyBERT is used to extract the top 5 most relevant keywords or keyphrases, considering both unigrams and bigrams.
#
# The model used is `all-MiniLM-L6-v2`, a lightweight and efficient sentence-transformer well-suited for semantic similarity tasks.
#
# The output is stored in a nested dictionary structure where each film maps to its thematic categories and the corresponding extracted keywords. The `tqdm` library is used to display a progress bar during processing, providing real-time feedback on the execution status.

# %%
# Initialize the KeyBERT model with a compact sentence-transformer
kw_model = KeyBERT(model="all-MiniLM-L6-v2")

# Dictionary to store the extracted keywords for each film and each theme
extracted_keywords = {}

# Iterate over all films with progress bar
for film in tqdm(all_summaries, desc="Processing films"):
    extracted_keywords[film] = {}
    
    # Iterate over all thematic sections within each film
    for theme, text in all_summaries[film].items():
        # Skip empty or missing text
        if not text.strip():
            extracted_keywords[film][theme] = []
            continue

        # Extract top 5 keywords or keyphrases (using unigrams and bigrams)
        keywords = kw_model.extract_keywords(
            text,
            keyphrase_ngram_range=(1, 2),
            stop_words="english",
            top_n=5,
            use_mmr=True,  # Promote diversity among keywords
        )

        # Store only the keyword strings (exclude scores)
        extracted_keywords[film][theme] = [kw for kw, _ in keywords]
# Out:
# Processing films: 100%|██████████| 12/12 [00:36<00:00,  3.02s/it]

# %%
for film, themes in extracted_keywords.items():
    print(f"\n=== Keywords for {film} ===\n")
    for theme, keywords in themes.items():
        if keywords:
            kw_list = ", ".join(keywords)
            print(f"{theme}: {kw_list}\n")
        else:
            print(f"{theme}: No keywords extracted.")
# Out:
# === Keywords for Parasite ===
#
# summary: parasite, director bong, thriller horror, writing critics, class disparity
#
# Cinematography: cinematography breathtaking, storytelling enhances, captivating immersive, composition visual, reviewers say
#
# Dark humor: dark humor, film memorable, shift tones, characters situations, blending seamlessly
#
# Direction: blends genres, film pacing, direction seen, appreciate director, manipulates emotions
#
# Dramatic tension: engaging climax, enhance suspense, dramatic tension, film masterfully, particularly praised
#
# Suspenseful: builds suspense, immersive thrilling, cinematography sound, intricate plot, described gripping
#
# Narrative complexity: narrative complexity, blend genres, depth criticized, innovative disorienting, twists plot
#
# Social commentary: social commentary, characters stereotypical, depth criticized, disparities moral, realism film
#
# Symbolism: use symbolism, depth criticized, storytelling, viewers appreciate, making film
#
# Thought-provoking: social commentary, opinions depth, class disparities, themes oversimplified, film offers
#
#
# === Keywords for Oppenheimer ===
#
# summary: oppenheimer role, christopher nolan, bomb development, themes moral, reviewers say
#
# Cinematography: cinematography breathtaking, immersive quality, imax 70mm, film praised, impact emotional
#
# Performance: praised standout, ensemble acting, performances universally, cillian murphy, authenticity characters
#
# Sound design: sound effects, effects explosions, bomb drop, movie success, design considered
#
# Historical accuracy: film historical, historical accuracy, factual representation, mixed impressions, dramatic storytelling
#
# Inner conflict: inner turmoil, portrayal character, narrative overly, opinions vary, compelling divisive
#
# Narrative complexity: narrative complexity, overwhelming timelines, depth criticized, content alienating, appreciate intricate
#
# Scientific depth: depiction quantum, understanding scientific, manhattan project, cgi, reviewers say
#
# Pacing: film pacing, trailer lacking, understanding narrative, characters felt, overwhelmingly negative
#
#
# === Keywords for The Good, the Bad and the Ugly ===
#
# summary: bad ugly, cinematography moral, performances morricone, leone direction, plot drawbacks
#
# Action sequences: gunfights intense, thrilling choreographed, action sequences, moments viewers, reviewers say
#
# Atmospheric: immersive atmosphere, thrilling visually, meticulous cinematography, elements praised, natural landscapes
#
# Cinematography: cinematography breathtaking, angle shots, frequently praised, meticulous framing, enhances epic
#
# Direction: compositions suspenseful, film standout, enhances storytelling, direction masterfully, wide shots
#
# Dramatic tension: scenes suspenseful, dramatic tension, climactic graveyard, morricone score, edge seats
#
# Great ensemble: eastwood lee, ensemble cast, performances breathe, van cleef, film narrative
#
# Iconic scene: standoff cemetery, final standoff, scene praised, excellence leaving, say final
#
# Iconic score: ennio morricone, haunting melodies, best cinema, score frequently, cited crucial
#
# Thin story: length criticized, story complexity, scenes lack, unfulfilled expectations, plot simplistic
#
#
# === Keywords for Harry Potter and the Sorcerer's Stone ===
#
# summary: stone acclaimed, potter sorcerer, book criticized, reviewers say, film pacing
#
# Chemistry: enjoyment film, particularly harry, characters feel, hermione significantly, strong chemistry
#
# Cinematography: cinematography exceptional, costumes immersive, effects praised, fantasy genre, bring magical
#
# Fantastical elements: hogwarts magical, imaginative aspects, create immersive, fantastical elements, film beloved
#
# Production design: imaginative designs, hogwarts diagon, film magical, forest praised, alley forbidden
#
# Set pieces: breathtaking hogwarts, costumes enhance, set pieces, quidditch match, gringotts looking
#
# Worldbuilding: wizarding world, audiences hogwarts, film worldbuilding, immersive detailed, iconic score
#
# Adaptation: cinematic adjustments, positive aspects, casting memorable, challenges translating, beloved book
#
# Character development: character development, adult cast, harry ron, feedback viewers, wooden lacking
#
# Performance: child actors, performances mixed, especially daniel, rickman robbie, received criticism
#
#
# === Keywords for Raiders of the Lost Ark ===
#
# summary: indiana jones, ark acclaimed, adventure iconic, raiders lost, enhance immersive
#
# Action sequences: action sequences, standout scenes, iconic truck, thrilling innovative, opening temple
#
# Comedic brilliance: ford humor, indiana jones, comedic brilliance, film memorable, adventure enhancing
#
# Iconic performance: ford portrayal, say harrison, heroism seamlessly, ability convey, frequently cited
#
# Iconic score: adventure john, theme praised, timeless appeal, best cinema, williams score
#
# Nostalgic: nostalgia enhances, viewers childhoods, appreciation film, adventure iconic, pop
#
# Production design: indiana jones, enhances immersive, iconic imagery, ruins greatly, production design
#
# Thrilling: thrilling adventure, action humor, standout genre, film ability, pace iconic
#
# Special effects: special effects, animatronics praised, realism, elements snakes, praised fantastical
#
# Character development: characters criticized, lack character, supporting characters, superficiality narrative, lack depth
#
# Thin story: narrative lacks, plot overly, action scenes, critics point, cohesive adventure
#
#
# === Keywords for Star Wars Episode 3 ===
#
# summary: sith lauded, prequel trilogy, fall anakin, dialogue hayden, criticism pacing
#
# Action sequences: lightsaber duels, sequences thrilling, battles praised, standout moments, say action
#
# Dark tone: dark tone, darker narrative, prequel trilogy, film emotional, depth intensity
#
# Emotional weight: film emotional, anakin fall, vader resonates, profoundly impactful, standout series
#
# Iconic scene: duel anakin, mustafar stands, iconic scene, highlight film, obi
#
# Inner conflict: nuance anakin, jedi love, portrayal protagonist, powerful narrative, descent dark
#
# Special effects: special effects, cgi realistic, star wars, breathtaking, battles enhance
#
# Character development: lacking anakin, character development, vader feeling, jedi council, explained inconsistent
#
# Chemistry: especially anakin, lacked emotional, chemistry characters, padme felt, making interactions
#
# Dialogue: anakin melodramatic, dialogue shortcomings, padme particularly, cringe, script frequently
#
#
# === Keywords for Star Wars Episode 4 ===
#
# summary: star wars, iconic characters, effects storytelling, hero journey, widely praised
#
# Generational appeal: timeless storytelling, nostalgia excitement, beloved classic, film cultural, viewers appreciate
#
# Production design: miniatures models, special effects, building iconic, create visually, say immersive
#
# Realism: universe realistic, detailed alien, immersive world, film ability, characters motivations
#
# Special effects: revolutionary effects, death star, immersive experience, space battles, future films
#
# Worldbuilding: mythology resonates, universe captivates, immersive expansive, creates compelling, alien
#
# Dubbing: actors dubbing, vader criticizing, exaggerated dialogue, performances mixed, character perception
#
# Character development: leia stereotypical, character development, dimensional lack, disappointment movie, criticize lack
#
# Derivative: lord rings, criticize plot, lacks originality, emphasizing film, archetypal dimensional
#
# Dialogue: dialogue criticized, princess leia, corny lacking, frequently described, depth lines
#
#
# === Keywords for Star Wars Episode 5 ===
#
# summary: empire strikes, vader true, like yoda, enrich narrative, revelation significantly
#
# Action sequences: lightsaber duel, vader scenes, action sequences, scenes praised, thrilling executed
#
# Character development: luke han, character praised, vader complexity, deepening characters, audience invested
#
# Cinematography: cinematography breathtaking, millennium falcon, ats hoth, chase framing, locations feel
#
# Dark tone: darker tone, film emotional, richer immersive, storytelling resonating, character development
#
# Iconic lines: significance dialogue, quotes like, say film, know ingrained, lines frequently
#
# Iconic scene: battle hoth, yoda cloud, luke training, showdown unforgettable, deeply audiences
#
# Iconic score: soundtrack considered, williams score, best cinema, praised unforgettable, atmosphere emotional
#
# Special effects: special effects, yoda iconic, cgi overall, asteroid chase, cloud city
#
# Suspenseful: film suspenseful, showdown luke, asteroid field, atmosphere story, seats significantly
#
# Worldbuilding: immersive detailed, yoda lando, universe seamless, diverse alien, iconic locations
#
#
# === Keywords for Star Wars Episode 6 ===
#
# summary: return jedi, criticized film, varied responses, like ewoks, legacy despite
#
# Action sequences: emperor scenes, action sequences, confrontation luke, endor battle, praised excitement
#
# Character development: particularly luke, character development, powerful jedi, leia maturation, emotional impact
#
# Emotional weight: vader redemption, especially luke, emotional weight, film powerful, character arcs
#
# Iconic ending: finale praised, iconic ending, trilogy satisfying, vader climactic, battle scenes
#
# Satisfying ending: finale, trilogy meaningful, defeat empire, vader climactic, scenes praised
#
# Special effects: special effects, groundbreaking memorable, hutt ewoks, like jabba, space battles
#
# Creature design: hutt scenes, disappointment ewoks, criticized cartoonish, story jabba, creature design
#
# Generational appeal: appeal alienating, younger audiences, previous films, ewoks cutesy, darker tone
#
# Pacing: inconsistent pacing, sections criticized, film effectiveness, jabba hutt, story disjointed
#
#
# === Keywords for Star Wars Episode 7 ===
#
# summary: force awakens, highlights criticized, new characters, ridley john, especially daisy
#
# Action sequences: lightsaber duels, action sequences, realism pacing, fans choreography, effects praised
#
# Character development: portrayal kylo, finn poe, new characters, chemistry rey, depth nostalgia
#
# Chemistry: rey finn, blend humor, resonates audiences, interactions characters, chemistry cast
#
# Direction: original trilogy, blending nostalgia, character development, cgi highlighted, pacing action
#
# Nostalgic: film nostalgic, trilogy use, iconic characters, enhances feeling, music visual
#
# Practical effects: effects cgi, realism immersion, props costumes, creating creatures, standout feature
#
# Suspenseful: film suspense, excitement familiarity, old characters, lack originality, story elements
#
# Derivative: nostalgia contribute, star wars, iconic characters, criticized lack, story derivative
#
# Uneven quality: inconsistent quality, film suffers, viewers disappointed, pacing lack, storytelling contribute
#
#
# === Keywords for Star Wars Episode 8 ===
#
# summary: wars jedi, portrayal luke, especially rey, criticized plot, praise innovative
#
# Action sequences: intense lightsaber, thrilling choreographed, action sequences, scenes highlight, dynamic camera
#
# Cinematography: cinematography praised, visuals breathtaking, effects cgi, imaginative storytelling, space battles
#
# Direction: praised narrative, direction ambitious, frequently criticized, underdeveloped characters, visuals effects
#
# Emotional weight: emotional weight, rey journey, especially character, impact lacking, varies finding
#
# Subversive: skywalker characterization, rey origins, divided opinions, film subversive, bold storytelling
#
# Character development: criticized snoke, character development, like luke, lack depth, viewers unsatisfied
#
# Legacy: film disrespected, luke skywalker, legacy franchise, reviewers say, disappointment sense
#
# Pacing: pacing severely, severely criticized, film dragged, scenes particularly, canto bight
#
#
# === Keywords for Star Wars Episode 9 ===
#
# summary: conclusion skywalker, trilogy contentious, wars rise, reviewers say, praise nostalgic
#
# Action sequences: action scenes, sequences thrilling, choreography special, intense executed, effects enhance
#
# Cinematography: cinematography spectacular, popping visuals, reviewers say, standout aspect, treat eyes
#
# Emotional stakes: beloved characters, emotional stakes, nostalgia satisfaction, closure saga, heightened return
#
# Special effects: cinematic experience, special effects, lightsaber duels, use cgi, highly praised
#
# Visual spectacle: effects cinematography, design breathtaking, quality impact, particularly praised, experience action
#
# Character development: character development, rey arcs, poe lacking, criticize finn, overall opinions
#
# Legacy: film legacy, trilogy standards, criticize, saga receives, plot inconsistencies
#
# Pacing: movie rushed, pacing overwhelmingly, criticized detracting, characters felt, story develop
#
# Thin story: characters criticized, narrative lacks, compelling storyline, depth plot, service nostalgia
#
# Uneven quality: film suffers, uneven quality, standout performances, adam driver, coherent narrative
