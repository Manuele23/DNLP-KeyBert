# %% [markdown]
# # AI-Generated Review Summaries: Keyword Extraction and Integration

# %% [markdown]
# This notebook analyzes a dictionary containing AI-generated summaries based on audience reviews of various films. Each entry includes a general film summary and detailed commentary on thematic aspects such as cinematography, direction, character development, narrative complexity, and others.
#
# The objective is to extract relevant keywords from these subjective textual summaries. Since the source content is rooted in user reviews, the extracted keywords effectively capture audience interpretations and reception patterns beyond mere plot descriptions.
#
# These keywords are filtered to remove duplicates and non-informative phrases (e.g., "reviewers say"), then ranked by relevance scores. They are integrated into the existing keyword dataset `keywords_ground_truth.pkl`, which primarily contains plot-based keywords. This integration enriches the dataset with audience-perspective descriptors, improving its coverage and relevance.
#
# New keywords are assigned incremental "Helpful" vote counts starting above the highest existing votes for each film, ensuring that more relevant keywords receive higher votes consistent with their scores.
#
# > **Note:** AI-generated summaries for *Star Wars: Episode I – The Phantom Menace*, *Star Wars: Episode II – Attack of the Clones*, and *La La Land* are currently missing from the dataset.

# %% [markdown]
# ## Setup: Installing and Importing Required Libraries

# %%
import subprocess
import sys

# List of required packages
required_packages = [
    "pandas", "pickle", "keybert", "sentence-transformers", "tqdm"
]

def install_package(package):
    """Installs a package using pip if it's not already installed."""
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Check and install missing packages
for package in required_packages:
    install_package(package)
# Out:
# pandas is already installed.
# pickle is already installed.
# keybert is already installed.
# Installing sentence-transformers...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentence-transformers in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.46.3)
# Requirement already satisfied: tqdm in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.67.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/manuelemustari/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# tqdm is already installed.

# %%
import pandas as pd
import pickle
from keybert import KeyBERT
from tqdm import tqdm

# %% [markdown]
# ## Load the dictionary with the AI-generated summary

# %% [markdown]
# This cell loads a dictionary containing AI-generated summaries from the file `summary_IA.pkl`. Each dictionary entry corresponds to a specific film and includes a general summary alongside detailed thematic evaluations such as cinematography, direction, character development, and more.
#
# The total number of films with available summaries is printed to confirm successful loading and provide an overview of the dataset size.

# %%
# Load the dictionary containing AI-generated summaries
with open("../Dataset/summary_IA.pkl", "rb") as f:
    all_summaries = pickle.load(f)

# Print how many films are included
print(f"Loaded summaries for {len(all_summaries)} films.\n")

# Show the structure (themes) for the first few films nicely formatted
for i, (film, themes) in enumerate(all_summaries.items()):
    if i >= 3:  # limit to first 3 films
        break
    print(f"Film: {film}")
    print("Themes included:")
    for theme in themes.keys():
        print(f"  - {theme}")
    print()
# Out:
# Loaded summaries for 12 films.
#
# Film: Parasite
# Themes included:
#   - summary
#   - Cinematography
#   - Dark humor
#   - Direction
#   - Dramatic tension
#   - Suspenseful
#   - Narrative complexity
#   - Social commentary
#   - Symbolism
#   - Thought-provoking
#
# Film: Oppenheimer
# Themes included:
#   - summary
#   - Cinematography
#   - Performance
#   - Sound design
#   - Historical accuracy
#   - Inner conflict
#   - Narrative complexity
#   - Scientific depth
#   - Pacing
#
# Film: The Good, the Bad and the Ugly
# Themes included:
#   - summary
#   - Action sequences
#   - Atmospheric
#   - Cinematography
#   - Direction
#   - Dramatic tension
#   - Great ensemble
#   - Iconic scene
#   - Iconic score
#   - Thin story

# %% [markdown]
# ## Keyword Extraction from AI-Generated Summaries Using KeyBERT

# %% [markdown]
# This cell initializes the KeyBERT model using the compact `"all-MiniLM-L6-v2"` transformer, optimized for efficient keyword extraction.
#
# It iterates over the AI-generated summaries for each film and each thematic section, extracting the top 5 keywords or keyphrases per text. The extraction considers unigrams and bigrams and applies Maximal Marginal Relevance (MMR) to promote diversity among the selected keywords.
#
# The extracted keywords are stored as tuples containing the keyword and its relevance score, organized in a nested dictionary structure keyed by film and theme. Empty or missing texts are skipped gracefully.

# %%
# Initialize the KeyBERT model with a compact sentence-transformer
kw_model = KeyBERT(model="all-MiniLM-L6-v2")

# Dictionary to store the extracted keywords and their scores for each film and each theme
extracted_keywords = {}

# Iterate over all films with progress bar
for film in tqdm(all_summaries, desc="Processing films"):
    extracted_keywords[film] = {}
    
    # Iterate over all thematic sections within each film
    for theme, text in all_summaries[film].items():
        # Skip empty or missing text
        if not text.strip():
            extracted_keywords[film][theme] = []
            continue

        # Extract top 5 keywords or keyphrases (using unigrams and bigrams)
        keywords = kw_model.extract_keywords(
            text,
            keyphrase_ngram_range=(1, 2),
            stop_words="english",
            top_n=5,
            use_mmr=True,  # Promote diversity among keywords
        )

        # Store tuples of (keyword, score)
        extracted_keywords[film][theme] = keywords
# Out:
# Processing films: 100%|██████████| 12/12 [00:36<00:00,  3.03s/it]

# %% [markdown]
# This cell below iterates over the extracted keywords dictionary, which contains thematic keyword lists with associated relevance scores for each film.
#
# For each film, it prints a clear header to separate the output visually. Then, for every thematic section within the film, it displays the extracted keywords formatted with their corresponding scores rounded to three decimal places. If no keywords were extracted for a particular theme, a message indicating the absence of keywords is printed instead.

# %%
# Iterate over each film and its associated thematic keyword lists with scores
for film, themes in extracted_keywords.items():
    # Print a header for each film to separate the output clearly
    print(f"\n=== Keywords for {film} ===\n")
    
    # Iterate over each theme and the list of (keyword, score) tuples extracted for that theme
    for theme, keywords in themes.items():
        # Check if there are any keywords extracted for the current theme
        if keywords:
            # Format each keyword with its score (rounded to 3 decimals)
            kw_list = ", ".join([f"{kw} ({score:.3f})" for kw, score in keywords])
            # Print the theme and its corresponding formatted keywords
            print(f"\t{theme}: {kw_list}\n")
        else:
            # Print a message if no keywords were extracted for the current theme
            print(f"{theme}: No keywords extracted.")
# Out:
# === Keywords for Parasite ===
#
# 	summary: parasite (0.629), director bong (0.379), thriller horror (0.363), writing critics (0.286), class disparity (0.195)
#
# 	Cinematography: cinematography breathtaking (0.751), storytelling enhances (0.487), captivating immersive (0.422), composition visual (0.381), reviewers say (0.258)
#
# 	Dark humor: dark humor (0.681), film memorable (0.390), shift tones (0.308), characters situations (0.286), blending seamlessly (0.190)
#
# 	Direction: blends genres (0.538), film pacing (0.496), direction seen (0.492), appreciate director (0.388), manipulates emotions (0.322)
#
# 	Dramatic tension: engaging climax (0.688), enhance suspense (0.635), dramatic tension (0.610), film masterfully (0.455), particularly praised (0.338)
#
# 	Suspenseful: builds suspense (0.710), immersive thrilling (0.594), cinematography sound (0.504), intricate plot (0.417), described gripping (0.381)
#
# 	Narrative complexity: narrative complexity (0.670), blend genres (0.495), depth criticized (0.493), innovative disorienting (0.325), twists plot (0.306)
#
# 	Social commentary: social commentary (0.661), characters stereotypical (0.478), depth criticized (0.462), disparities moral (0.430), realism film (0.352)
#
# 	Symbolism: use symbolism (0.713), depth criticized (0.370), storytelling (0.349), viewers appreciate (0.322), making film (0.248)
#
# 	Thought-provoking: social commentary (0.608), opinions depth (0.517), class disparities (0.432), themes oversimplified (0.383), film offers (0.289)
#
#
# === Keywords for Oppenheimer ===
#
# 	summary: oppenheimer role (0.608), christopher nolan (0.530), bomb development (0.504), themes moral (0.311), reviewers say (0.157)
#
# 	Cinematography: cinematography breathtaking (0.653), immersive quality (0.597), imax 70mm (0.565), film praised (0.519), impact emotional (0.231)
#
# 	Performance: praised standout (0.533), ensemble acting (0.527), performances universally (0.478), cillian murphy (0.435), authenticity characters (0.356)
#
# 	Sound design: sound effects (0.599), effects explosions (0.575), bomb drop (0.513), movie success (0.372), design considered (0.295)
#
# 	Historical accuracy: film historical (0.563), historical accuracy (0.462), factual representation (0.454), mixed impressions (0.392), dramatic storytelling (0.355)
#
# 	Inner conflict: inner turmoil (0.572), portrayal character (0.513), narrative overly (0.476), opinions vary (0.382), compelling divisive (0.361)
#
# 	Narrative complexity: narrative complexity (0.804), overwhelming timelines (0.438), depth criticized (0.381), content alienating (0.319), appreciate intricate (0.293)
#
# 	Scientific depth: depiction quantum (0.529), understanding scientific (0.451), manhattan project (0.438), cgi (0.405), reviewers say (0.233)
#
# 	Pacing: film pacing (0.646), trailer lacking (0.449), understanding narrative (0.374), characters felt (0.351), overwhelmingly negative (0.251)
#
#
# === Keywords for The Good, the Bad and the Ugly ===
#
# 	summary: bad ugly (0.560), cinematography moral (0.475), performances morricone (0.398), leone direction (0.387), plot drawbacks (0.347)
#
# 	Action sequences: gunfights intense (0.621), thrilling choreographed (0.608), action sequences (0.603), moments viewers (0.438), reviewers say (0.176)
#
# 	Atmospheric: immersive atmosphere (0.741), thrilling visually (0.549), meticulous cinematography (0.504), elements praised (0.437), natural landscapes (0.401)
#
# 	Cinematography: cinematography breathtaking (0.768), angle shots (0.432), frequently praised (0.402), meticulous framing (0.370), enhances epic (0.345)
#
# 	Direction: compositions suspenseful (0.564), film standout (0.503), enhances storytelling (0.487), direction masterfully (0.381), wide shots (0.361)
#
# 	Dramatic tension: scenes suspenseful (0.694), dramatic tension (0.569), climactic graveyard (0.463), morricone score (0.399), edge seats (0.160)
#
# 	Great ensemble: eastwood lee (0.552), ensemble cast (0.506), performances breathe (0.415), van cleef (0.404), film narrative (0.362)
#
# 	Iconic scene: standoff cemetery (0.661), final standoff (0.530), scene praised (0.492), excellence leaving (0.302), say final (0.184)
#
# 	Iconic score: ennio morricone (0.592), haunting melodies (0.465), best cinema (0.383), score frequently (0.205), cited crucial (0.192)
#
# 	Thin story: length criticized (0.537), story complexity (0.502), scenes lack (0.494), unfulfilled expectations (0.422), plot simplistic (0.216)
#
#
# === Keywords for Harry Potter and the Sorcerer's Stone ===
#
# 	summary: stone acclaimed (0.537), potter sorcerer (0.477), book criticized (0.441), reviewers say (0.377), film pacing (0.228)
#
# 	Chemistry: enjoyment film (0.496), particularly harry (0.453), characters feel (0.451), hermione significantly (0.387), strong chemistry (0.363)
#
# 	Cinematography: cinematography exceptional (0.634), costumes immersive (0.516), effects praised (0.504), fantasy genre (0.439), bring magical (0.344)
#
# 	Fantastical elements: hogwarts magical (0.665), imaginative aspects (0.485), create immersive (0.461), fantastical elements (0.455), film beloved (0.374)
#
# 	Production design: imaginative designs (0.557), hogwarts diagon (0.519), film magical (0.478), forest praised (0.355), alley forbidden (0.323)
#
# 	Set pieces: breathtaking hogwarts (0.657), costumes enhance (0.488), set pieces (0.399), quidditch match (0.386), gringotts looking (0.332)
#
# 	Worldbuilding: wizarding world (0.664), audiences hogwarts (0.560), film worldbuilding (0.510), immersive detailed (0.485), iconic score (0.269)
#
# 	Adaptation: cinematic adjustments (0.458), positive aspects (0.429), casting memorable (0.419), challenges translating (0.359), beloved book (0.339)
#
# 	Character development: character development (0.597), adult cast (0.466), harry ron (0.437), feedback viewers (0.295), wooden lacking (0.258)
#
# 	Performance: child actors (0.575), performances mixed (0.426), especially daniel (0.338), rickman robbie (0.324), received criticism (0.264)
#
#
# === Keywords for Raiders of the Lost Ark ===
#
# 	summary: indiana jones (0.564), ark acclaimed (0.559), adventure iconic (0.454), raiders lost (0.323), enhance immersive (0.317)
#
# 	Action sequences: action sequences (0.609), standout scenes (0.491), iconic truck (0.425), thrilling innovative (0.406), opening temple (0.282)
#
# 	Comedic brilliance: ford humor (0.639), indiana jones (0.525), comedic brilliance (0.505), film memorable (0.461), adventure enhancing (0.212)
#
# 	Iconic performance: ford portrayal (0.584), say harrison (0.397), heroism seamlessly (0.313), ability convey (0.307), frequently cited (0.080)
#
# 	Iconic score: adventure john (0.496), theme praised (0.496), timeless appeal (0.387), best cinema (0.381), williams score (0.343)
#
# 	Nostalgic: nostalgia enhances (0.734), viewers childhoods (0.523), appreciation film (0.467), adventure iconic (0.416), pop (0.216)
#
# 	Production design: indiana jones (0.569), enhances immersive (0.452), iconic imagery (0.388), ruins greatly (0.323), production design (0.268)
#
# 	Thrilling: thrilling adventure (0.640), action humor (0.460), standout genre (0.417), film ability (0.375), pace iconic (0.353)
#
# 	Special effects: special effects (0.676), animatronics praised (0.444), realism (0.361), elements snakes (0.344), praised fantastical (0.317)
#
# 	Character development: characters criticized (0.660), lack character (0.614), supporting characters (0.585), superficiality narrative (0.509), lack depth (0.376)
#
# 	Thin story: narrative lacks (0.589), plot overly (0.433), action scenes (0.399), critics point (0.398), cohesive adventure (0.284)
#
#
# === Keywords for Star Wars Episode 3 ===
#
# 	summary: sith lauded (0.605), prequel trilogy (0.560), fall anakin (0.446), dialogue hayden (0.439), criticism pacing (0.347)
#
# 	Action sequences: lightsaber duels (0.634), sequences thrilling (0.461), battles praised (0.426), standout moments (0.379), say action (0.318)
#
# 	Dark tone: dark tone (0.638), darker narrative (0.580), prequel trilogy (0.442), film emotional (0.420), depth intensity (0.281)
#
# 	Emotional weight: film emotional (0.569), anakin fall (0.504), vader resonates (0.417), profoundly impactful (0.348), standout series (0.276)
#
# 	Iconic scene: duel anakin (0.604), mustafar stands (0.522), iconic scene (0.416), highlight film (0.358), obi (0.307)
#
# 	Inner conflict: nuance anakin (0.630), jedi love (0.507), portrayal protagonist (0.425), powerful narrative (0.408), descent dark (0.357)
#
# 	Special effects: special effects (0.594), cgi realistic (0.547), star wars (0.496), breathtaking (0.405), battles enhance (0.352)
#
# 	Character development: lacking anakin (0.578), character development (0.498), vader feeling (0.477), jedi council (0.397), explained inconsistent (0.251)
#
# 	Chemistry: especially anakin (0.508), lacked emotional (0.435), chemistry characters (0.380), padme felt (0.357), making interactions (0.328)
#
# 	Dialogue: anakin melodramatic (0.667), dialogue shortcomings (0.608), padme particularly (0.331), cringe (0.324), script frequently (0.219)
#
#
# === Keywords for Star Wars Episode 4 ===
#
# 	summary: star wars (0.553), iconic characters (0.452), effects storytelling (0.432), hero journey (0.339), widely praised (0.325)
#
# 	Generational appeal: timeless storytelling (0.641), nostalgia excitement (0.506), beloved classic (0.448), film cultural (0.433), viewers appreciate (0.312)
#
# 	Production design: miniatures models (0.624), special effects (0.570), building iconic (0.481), create visually (0.433), say immersive (0.427)
#
# 	Realism: universe realistic (0.564), detailed alien (0.547), immersive world (0.532), film ability (0.382), characters motivations (0.335)
#
# 	Special effects: revolutionary effects (0.545), death star (0.499), immersive experience (0.483), space battles (0.461), future films (0.420)
#
# 	Worldbuilding: mythology resonates (0.545), universe captivates (0.453), immersive expansive (0.418), creates compelling (0.413), alien (0.388)
#
# 	Dubbing: actors dubbing (0.605), vader criticizing (0.501), exaggerated dialogue (0.498), performances mixed (0.398), character perception (0.391)
#
# 	Character development: leia stereotypical (0.558), character development (0.492), dimensional lack (0.401), disappointment movie (0.390), criticize lack (0.345)
#
# 	Derivative: lord rings (0.529), criticize plot (0.503), lacks originality (0.469), emphasizing film (0.422), archetypal dimensional (0.316)
#
# 	Dialogue: dialogue criticized (0.690), princess leia (0.393), corny lacking (0.341), frequently described (0.258), depth lines (0.249)
#
#
# === Keywords for Star Wars Episode 5 ===
#
# 	summary: empire strikes (0.617), vader true (0.408), like yoda (0.335), enrich narrative (0.315), revelation significantly (0.297)
#
# 	Action sequences: lightsaber duel (0.615), vader scenes (0.576), action sequences (0.474), scenes praised (0.472), thrilling executed (0.424)
#
# 	Character development: luke han (0.566), character praised (0.439), vader complexity (0.394), deepening characters (0.375), audience invested (0.247)
#
# 	Cinematography: cinematography breathtaking (0.594), millennium falcon (0.450), ats hoth (0.419), chase framing (0.405), locations feel (0.265)
#
# 	Dark tone: darker tone (0.617), film emotional (0.492), richer immersive (0.457), storytelling resonating (0.412), character development (0.351)
#
# 	Iconic lines: significance dialogue (0.495), quotes like (0.422), say film (0.409), know ingrained (0.370), lines frequently (0.216)
#
# 	Iconic scene: battle hoth (0.534), yoda cloud (0.492), luke training (0.464), showdown unforgettable (0.423), deeply audiences (0.326)
#
# 	Iconic score: soundtrack considered (0.561), williams score (0.378), best cinema (0.352), praised unforgettable (0.339), atmosphere emotional (0.265)
#
# 	Special effects: special effects (0.603), yoda iconic (0.464), cgi overall (0.440), asteroid chase (0.339), cloud city (0.310)
#
# 	Suspenseful: film suspenseful (0.535), showdown luke (0.508), asteroid field (0.337), atmosphere story (0.327), seats significantly (0.227)
#
# 	Worldbuilding: immersive detailed (0.541), yoda lando (0.469), universe seamless (0.401), diverse alien (0.394), iconic locations (0.383)
#
#
# === Keywords for Star Wars Episode 6 ===
#
# 	summary: return jedi (0.673), criticized film (0.370), varied responses (0.219), like ewoks (0.208), legacy despite (0.168)
#
# 	Action sequences: emperor scenes (0.537), action sequences (0.506), confrontation luke (0.455), endor battle (0.452), praised excitement (0.320)
#
# 	Character development: particularly luke (0.538), character development (0.490), powerful jedi (0.488), leia maturation (0.448), emotional impact (0.277)
#
# 	Emotional weight: vader redemption (0.572), especially luke (0.526), emotional weight (0.429), film powerful (0.377), character arcs (0.300)
#
# 	Iconic ending: finale praised (0.650), iconic ending (0.609), trilogy satisfying (0.485), vader climactic (0.479), battle scenes (0.370)
#
# 	Satisfying ending: finale (0.508), trilogy meaningful (0.491), defeat empire (0.466), vader climactic (0.462), scenes praised (0.426)
#
# 	Special effects: special effects (0.601), groundbreaking memorable (0.430), hutt ewoks (0.425), like jabba (0.372), space battles (0.344)
#
# 	Creature design: hutt scenes (0.498), disappointment ewoks (0.464), criticized cartoonish (0.427), story jabba (0.417), creature design (0.399)
#
# 	Generational appeal: appeal alienating (0.509), younger audiences (0.493), previous films (0.414), ewoks cutesy (0.396), darker tone (0.278)
#
# 	Pacing: inconsistent pacing (0.594), sections criticized (0.423), film effectiveness (0.384), jabba hutt (0.350), story disjointed (0.310)
#
#
# === Keywords for Star Wars Episode 7 ===
#
# 	summary: force awakens (0.655), highlights criticized (0.284), new characters (0.266), ridley john (0.225), especially daisy (0.210)
#
# 	Action sequences: lightsaber duels (0.578), action sequences (0.498), realism pacing (0.491), fans choreography (0.427), effects praised (0.419)
#
# 	Character development: portrayal kylo (0.582), finn poe (0.495), new characters (0.422), chemistry rey (0.414), depth nostalgia (0.363)
#
# 	Chemistry: rey finn (0.615), blend humor (0.383), resonates audiences (0.378), interactions characters (0.377), chemistry cast (0.364)
#
# 	Direction: original trilogy (0.511), blending nostalgia (0.476), character development (0.395), cgi highlighted (0.339), pacing action (0.303)
#
# 	Nostalgic: film nostalgic (0.686), trilogy use (0.395), iconic characters (0.382), enhances feeling (0.373), music visual (0.293)
#
# 	Practical effects: effects cgi (0.642), realism immersion (0.640), props costumes (0.396), creating creatures (0.367), standout feature (0.298)
#
# 	Suspenseful: film suspense (0.678), excitement familiarity (0.482), old characters (0.367), lack originality (0.348), story elements (0.344)
#
# 	Derivative: nostalgia contribute (0.488), star wars (0.475), iconic characters (0.415), criticized lack (0.347), story derivative (0.345)
#
# 	Uneven quality: inconsistent quality (0.496), film suffers (0.491), viewers disappointed (0.483), pacing lack (0.425), storytelling contribute (0.393)
#
#
# === Keywords for Star Wars Episode 8 ===
#
# 	summary: wars jedi (0.552), portrayal luke (0.465), especially rey (0.451), criticized plot (0.410), praise innovative (0.196)
#
# 	Action sequences: intense lightsaber (0.639), thrilling choreographed (0.509), action sequences (0.497), scenes highlight (0.451), dynamic camera (0.316)
#
# 	Cinematography: cinematography praised (0.696), visuals breathtaking (0.627), effects cgi (0.518), imaginative storytelling (0.348), space battles (0.212)
#
# 	Direction: praised narrative (0.555), direction ambitious (0.475), frequently criticized (0.456), underdeveloped characters (0.408), visuals effects (0.401)
#
# 	Emotional weight: emotional weight (0.622), rey journey (0.420), especially character (0.355), impact lacking (0.326), varies finding (0.140)
#
# 	Subversive: skywalker characterization (0.522), rey origins (0.516), divided opinions (0.484), film subversive (0.430), bold storytelling (0.335)
#
# 	Character development: criticized snoke (0.466), character development (0.437), like luke (0.366), lack depth (0.358), viewers unsatisfied (0.339)
#
# 	Legacy: film disrespected (0.488), luke skywalker (0.432), legacy franchise (0.339), reviewers say (0.310), disappointment sense (0.263)
#
# 	Pacing: pacing severely (0.518), severely criticized (0.492), film dragged (0.489), scenes particularly (0.388), canto bight (0.224)
#
#
# === Keywords for Star Wars Episode 9 ===
#
# 	summary: conclusion skywalker (0.583), trilogy contentious (0.392), wars rise (0.388), reviewers say (0.330), praise nostalgic (0.236)
#
# 	Action sequences: action scenes (0.702), sequences thrilling (0.537), choreography special (0.525), intense executed (0.412), effects enhance (0.306)
#
# 	Cinematography: cinematography spectacular (0.628), popping visuals (0.328), reviewers say (0.318), standout aspect (0.318), treat eyes (0.219)
#
# 	Emotional stakes: beloved characters (0.566), emotional stakes (0.540), nostalgia satisfaction (0.523), closure saga (0.343), heightened return (0.317)
#
# 	Special effects: cinematic experience (0.553), special effects (0.532), lightsaber duels (0.524), use cgi (0.492), highly praised (0.302)
#
# 	Visual spectacle: effects cinematography (0.684), design breathtaking (0.587), quality impact (0.395), particularly praised (0.354), experience action (0.316)
#
# 	Character development: character development (0.574), rey arcs (0.465), poe lacking (0.455), criticize finn (0.426), overall opinions (0.290)
#
# 	Legacy: film legacy (0.635), trilogy standards (0.467), criticize (0.344), saga receives (0.281), plot inconsistencies (0.236)
#
# 	Pacing: movie rushed (0.650), pacing overwhelmingly (0.563), criticized detracting (0.355), characters felt (0.334), story develop (0.317)
#
# 	Thin story: characters criticized (0.645), narrative lacks (0.530), compelling storyline (0.522), depth plot (0.324), service nostalgia (0.317)
#
# 	Uneven quality: film suffers (0.507), uneven quality (0.498), standout performances (0.375), adam driver (0.352), coherent narrative (0.348)

# %% [markdown]
# This cell consolidates the extracted keywords for each film by aggregating all thematic keyword lists into a single set of unique keywords.
# For each keyword, only the highest relevance score across all themes is retained. To improve data quality, the phrase "reviewers say" (case-insensitive) is explicitly removed if present.
#
# The keywords are then sorted in descending order by their maximum scores and printed alongside their scores rounded to three decimal places.

# %%
# Iterate over each film and its associated thematic keyword lists with scores
for film, themes in extracted_keywords.items():
    # Temporary dictionary to store the highest score for each keyword
    keyword_max_scores = {}

    # Loop through all lists of (keyword, score) tuples across all categories
    for keywords in themes.values():
        for kw, score in keywords:
            # Update the maximum score for each keyword encountered
            if kw not in keyword_max_scores or score > keyword_max_scores[kw]:
                keyword_max_scores[kw] = score

    # Remove the keyword "reviewers say" if present (case insensitive)
    to_remove_reviewers_say = [kw for kw in keyword_max_scores if kw.lower() == "reviewers say"]
    for kw in to_remove_reviewers_say:
        keyword_max_scores.pop(kw)

    # Sort the keywords by their maximum score in descending order
    sorted_keywords = sorted(keyword_max_scores.items(), key=lambda x: x[1], reverse=True)

    # Print the film header with total unique keywords count
    print(f"\n=== Unique Keywords for {film} (total: {len(sorted_keywords)}) ===")
    
    # If keywords exist, print them with scores rounded to 3 decimals
    if sorted_keywords:
        print(", ".join([f"{kw} ({score:.3f})" for kw, score in sorted_keywords]))
    else:
        # Inform if no keywords were extracted for the film
        print("No keywords extracted.")
# Out:
# === Unique Keywords for Parasite (total: 46) ===
# cinematography breathtaking (0.751), use symbolism (0.713), builds suspense (0.710), engaging climax (0.688), dark humor (0.681), narrative complexity (0.670), social commentary (0.661), enhance suspense (0.635), parasite (0.629), dramatic tension (0.610), immersive thrilling (0.594), blends genres (0.538), opinions depth (0.517), cinematography sound (0.504), film pacing (0.496), blend genres (0.495), depth criticized (0.493), direction seen (0.492), storytelling enhances (0.487), characters stereotypical (0.478), film masterfully (0.455), class disparities (0.432), disparities moral (0.430), captivating immersive (0.422), intricate plot (0.417), film memorable (0.390), appreciate director (0.388), themes oversimplified (0.383), composition visual (0.381), described gripping (0.381), director bong (0.379), thriller horror (0.363), realism film (0.352), storytelling (0.349), particularly praised (0.338), innovative disorienting (0.325), viewers appreciate (0.322), manipulates emotions (0.322), shift tones (0.308), twists plot (0.306), film offers (0.289), writing critics (0.286), characters situations (0.286), making film (0.248), class disparity (0.195), blending seamlessly (0.190)
#
# === Unique Keywords for Oppenheimer (total: 43) ===
# narrative complexity (0.804), cinematography breathtaking (0.653), film pacing (0.646), oppenheimer role (0.608), sound effects (0.599), immersive quality (0.597), effects explosions (0.575), inner turmoil (0.572), imax 70mm (0.565), film historical (0.563), praised standout (0.533), christopher nolan (0.530), depiction quantum (0.529), ensemble acting (0.527), film praised (0.519), portrayal character (0.513), bomb drop (0.513), bomb development (0.504), performances universally (0.478), narrative overly (0.476), historical accuracy (0.462), factual representation (0.454), understanding scientific (0.451), trailer lacking (0.449), manhattan project (0.438), overwhelming timelines (0.438), cillian murphy (0.435), cgi (0.405), mixed impressions (0.392), opinions vary (0.382), depth criticized (0.381), understanding narrative (0.374), movie success (0.372), compelling divisive (0.361), authenticity characters (0.356), dramatic storytelling (0.355), characters felt (0.351), content alienating (0.319), themes moral (0.311), design considered (0.295), appreciate intricate (0.293), overwhelmingly negative (0.251), impact emotional (0.231)
#
# === Unique Keywords for The Good, the Bad and the Ugly (total: 49) ===
# cinematography breathtaking (0.768), immersive atmosphere (0.741), scenes suspenseful (0.694), standoff cemetery (0.661), gunfights intense (0.621), thrilling choreographed (0.608), action sequences (0.603), ennio morricone (0.592), dramatic tension (0.569), compositions suspenseful (0.564), bad ugly (0.560), eastwood lee (0.552), thrilling visually (0.549), length criticized (0.537), final standoff (0.530), ensemble cast (0.506), meticulous cinematography (0.504), film standout (0.503), story complexity (0.502), scenes lack (0.494), scene praised (0.492), enhances storytelling (0.487), cinematography moral (0.475), haunting melodies (0.465), climactic graveyard (0.463), moments viewers (0.438), elements praised (0.437), angle shots (0.432), unfulfilled expectations (0.422), performances breathe (0.415), van cleef (0.404), frequently praised (0.402), natural landscapes (0.401), morricone score (0.399), performances morricone (0.398), leone direction (0.387), best cinema (0.383), direction masterfully (0.381), meticulous framing (0.370), film narrative (0.362), wide shots (0.361), plot drawbacks (0.347), enhances epic (0.345), excellence leaving (0.302), plot simplistic (0.216), score frequently (0.205), cited crucial (0.192), say final (0.184), edge seats (0.160)
#
# === Unique Keywords for Harry Potter and the Sorcerer's Stone (total: 49) ===
# hogwarts magical (0.665), wizarding world (0.664), breathtaking hogwarts (0.657), cinematography exceptional (0.634), character development (0.597), child actors (0.575), audiences hogwarts (0.560), imaginative designs (0.557), stone acclaimed (0.537), hogwarts diagon (0.519), costumes immersive (0.516), film worldbuilding (0.510), effects praised (0.504), enjoyment film (0.496), costumes enhance (0.488), immersive detailed (0.485), imaginative aspects (0.485), film magical (0.478), potter sorcerer (0.477), adult cast (0.466), create immersive (0.461), cinematic adjustments (0.458), fantastical elements (0.455), particularly harry (0.453), characters feel (0.451), book criticized (0.441), fantasy genre (0.439), harry ron (0.437), positive aspects (0.429), performances mixed (0.426), casting memorable (0.419), set pieces (0.399), hermione significantly (0.387), quidditch match (0.386), film beloved (0.374), strong chemistry (0.363), challenges translating (0.359), forest praised (0.355), bring magical (0.344), beloved book (0.339), especially daniel (0.338), gringotts looking (0.332), rickman robbie (0.324), alley forbidden (0.323), feedback viewers (0.295), iconic score (0.269), received criticism (0.264), wooden lacking (0.258), film pacing (0.228)
#
# === Unique Keywords for Raiders of the Lost Ark (total: 52) ===
# nostalgia enhances (0.734), special effects (0.676), characters criticized (0.660), thrilling adventure (0.640), ford humor (0.639), lack character (0.614), action sequences (0.609), narrative lacks (0.589), supporting characters (0.585), ford portrayal (0.584), indiana jones (0.569), ark acclaimed (0.559), viewers childhoods (0.523), superficiality narrative (0.509), comedic brilliance (0.505), adventure john (0.496), theme praised (0.496), standout scenes (0.491), appreciation film (0.467), film memorable (0.461), action humor (0.460), adventure iconic (0.454), enhances immersive (0.452), animatronics praised (0.444), plot overly (0.433), iconic truck (0.425), standout genre (0.417), thrilling innovative (0.406), action scenes (0.399), critics point (0.398), say harrison (0.397), iconic imagery (0.388), timeless appeal (0.387), best cinema (0.381), lack depth (0.376), film ability (0.375), realism (0.361), pace iconic (0.353), elements snakes (0.344), williams score (0.343), ruins greatly (0.323), raiders lost (0.323), praised fantastical (0.317), enhance immersive (0.317), heroism seamlessly (0.313), ability convey (0.307), cohesive adventure (0.284), opening temple (0.282), production design (0.268), pop (0.216), adventure enhancing (0.212), frequently cited (0.080)
#
# === Unique Keywords for Star Wars Episode 3 (total: 48) ===
# anakin melodramatic (0.667), dark tone (0.638), lightsaber duels (0.634), nuance anakin (0.630), dialogue shortcomings (0.608), sith lauded (0.605), duel anakin (0.604), special effects (0.594), darker narrative (0.580), lacking anakin (0.578), film emotional (0.569), prequel trilogy (0.560), cgi realistic (0.547), mustafar stands (0.522), especially anakin (0.508), jedi love (0.507), anakin fall (0.504), character development (0.498), star wars (0.496), vader feeling (0.477), sequences thrilling (0.461), fall anakin (0.446), dialogue hayden (0.439), lacked emotional (0.435), battles praised (0.426), portrayal protagonist (0.425), vader resonates (0.417), iconic scene (0.416), powerful narrative (0.408), breathtaking (0.405), jedi council (0.397), chemistry characters (0.380), standout moments (0.379), highlight film (0.358), padme felt (0.357), descent dark (0.357), battles enhance (0.352), profoundly impactful (0.348), criticism pacing (0.347), padme particularly (0.331), making interactions (0.328), cringe (0.324), say action (0.318), obi (0.307), depth intensity (0.281), standout series (0.276), explained inconsistent (0.251), script frequently (0.219)
#
# === Unique Keywords for Star Wars Episode 4 (total: 50) ===
# dialogue criticized (0.690), timeless storytelling (0.641), miniatures models (0.624), actors dubbing (0.605), special effects (0.570), universe realistic (0.564), leia stereotypical (0.558), star wars (0.553), detailed alien (0.547), mythology resonates (0.545), revolutionary effects (0.545), immersive world (0.532), lord rings (0.529), nostalgia excitement (0.506), criticize plot (0.503), vader criticizing (0.501), death star (0.499), exaggerated dialogue (0.498), character development (0.492), immersive experience (0.483), building iconic (0.481), lacks originality (0.469), space battles (0.461), universe captivates (0.453), iconic characters (0.452), beloved classic (0.448), film cultural (0.433), create visually (0.433), effects storytelling (0.432), say immersive (0.427), emphasizing film (0.422), future films (0.420), immersive expansive (0.418), creates compelling (0.413), dimensional lack (0.401), performances mixed (0.398), princess leia (0.393), character perception (0.391), disappointment movie (0.390), alien (0.388), film ability (0.382), criticize lack (0.345), corny lacking (0.341), hero journey (0.339), characters motivations (0.335), widely praised (0.325), archetypal dimensional (0.316), viewers appreciate (0.312), frequently described (0.258), depth lines (0.249)
#
# === Unique Keywords for Star Wars Episode 5 (total: 55) ===
# empire strikes (0.617), darker tone (0.617), lightsaber duel (0.615), special effects (0.603), cinematography breathtaking (0.594), vader scenes (0.576), luke han (0.566), soundtrack considered (0.561), immersive detailed (0.541), film suspenseful (0.535), battle hoth (0.534), showdown luke (0.508), significance dialogue (0.495), film emotional (0.492), yoda cloud (0.492), action sequences (0.474), scenes praised (0.472), yoda lando (0.469), yoda iconic (0.464), luke training (0.464), richer immersive (0.457), millennium falcon (0.450), cgi overall (0.440), character praised (0.439), thrilling executed (0.424), showdown unforgettable (0.423), quotes like (0.422), ats hoth (0.419), storytelling resonating (0.412), say film (0.409), vader true (0.408), chase framing (0.405), universe seamless (0.401), diverse alien (0.394), vader complexity (0.394), iconic locations (0.383), williams score (0.378), deepening characters (0.375), know ingrained (0.370), best cinema (0.352), character development (0.351), praised unforgettable (0.339), asteroid chase (0.339), asteroid field (0.337), like yoda (0.335), atmosphere story (0.327), deeply audiences (0.326), enrich narrative (0.315), cloud city (0.310), revelation significantly (0.297), locations feel (0.265), atmosphere emotional (0.265), audience invested (0.247), seats significantly (0.227), lines frequently (0.216)
#
# === Unique Keywords for Star Wars Episode 6 (total: 49) ===
# return jedi (0.673), finale praised (0.650), iconic ending (0.609), special effects (0.601), inconsistent pacing (0.594), vader redemption (0.572), particularly luke (0.538), emperor scenes (0.537), especially luke (0.526), appeal alienating (0.509), finale (0.508), action sequences (0.506), hutt scenes (0.498), younger audiences (0.493), trilogy meaningful (0.491), character development (0.490), powerful jedi (0.488), trilogy satisfying (0.485), vader climactic (0.479), defeat empire (0.466), disappointment ewoks (0.464), confrontation luke (0.455), endor battle (0.452), leia maturation (0.448), groundbreaking memorable (0.430), emotional weight (0.429), criticized cartoonish (0.427), scenes praised (0.426), hutt ewoks (0.425), sections criticized (0.423), story jabba (0.417), previous films (0.414), creature design (0.399), ewoks cutesy (0.396), film effectiveness (0.384), film powerful (0.377), like jabba (0.372), battle scenes (0.370), criticized film (0.370), jabba hutt (0.350), space battles (0.344), praised excitement (0.320), story disjointed (0.310), character arcs (0.300), darker tone (0.278), emotional impact (0.277), varied responses (0.219), like ewoks (0.208), legacy despite (0.168)
#
# === Unique Keywords for Star Wars Episode 7 (total: 48) ===
# film nostalgic (0.686), film suspense (0.678), force awakens (0.655), effects cgi (0.642), realism immersion (0.640), rey finn (0.615), portrayal kylo (0.582), lightsaber duels (0.578), original trilogy (0.511), action sequences (0.498), inconsistent quality (0.496), finn poe (0.495), film suffers (0.491), realism pacing (0.491), nostalgia contribute (0.488), viewers disappointed (0.483), excitement familiarity (0.482), blending nostalgia (0.476), star wars (0.475), fans choreography (0.427), pacing lack (0.425), new characters (0.422), effects praised (0.419), iconic characters (0.415), chemistry rey (0.414), props costumes (0.396), trilogy use (0.395), character development (0.395), storytelling contribute (0.393), blend humor (0.383), resonates audiences (0.378), interactions characters (0.377), enhances feeling (0.373), old characters (0.367), creating creatures (0.367), chemistry cast (0.364), depth nostalgia (0.363), lack originality (0.348), criticized lack (0.347), story derivative (0.345), story elements (0.344), cgi highlighted (0.339), pacing action (0.303), standout feature (0.298), music visual (0.293), highlights criticized (0.284), ridley john (0.225), especially daisy (0.210)
#
# === Unique Keywords for Star Wars Episode 8 (total: 44) ===
# cinematography praised (0.696), intense lightsaber (0.639), visuals breathtaking (0.627), emotional weight (0.622), praised narrative (0.555), wars jedi (0.552), skywalker characterization (0.522), pacing severely (0.518), effects cgi (0.518), rey origins (0.516), thrilling choreographed (0.509), action sequences (0.497), severely criticized (0.492), film dragged (0.489), film disrespected (0.488), divided opinions (0.484), direction ambitious (0.475), criticized snoke (0.466), portrayal luke (0.465), frequently criticized (0.456), especially rey (0.451), scenes highlight (0.451), character development (0.437), luke skywalker (0.432), film subversive (0.430), rey journey (0.420), criticized plot (0.410), underdeveloped characters (0.408), visuals effects (0.401), scenes particularly (0.388), like luke (0.366), lack depth (0.358), especially character (0.355), imaginative storytelling (0.348), legacy franchise (0.339), viewers unsatisfied (0.339), bold storytelling (0.335), impact lacking (0.326), dynamic camera (0.316), disappointment sense (0.263), canto bight (0.224), space battles (0.212), praise innovative (0.196), varies finding (0.140)
#
# === Unique Keywords for Star Wars Episode 9 (total: 53) ===
# action scenes (0.702), effects cinematography (0.684), movie rushed (0.650), characters criticized (0.645), film legacy (0.635), cinematography spectacular (0.628), design breathtaking (0.587), conclusion skywalker (0.583), character development (0.574), beloved characters (0.566), pacing overwhelmingly (0.563), cinematic experience (0.553), emotional stakes (0.540), sequences thrilling (0.537), special effects (0.532), narrative lacks (0.530), choreography special (0.525), lightsaber duels (0.524), nostalgia satisfaction (0.523), compelling storyline (0.522), film suffers (0.507), uneven quality (0.498), use cgi (0.492), trilogy standards (0.467), rey arcs (0.465), poe lacking (0.455), criticize finn (0.426), intense executed (0.412), quality impact (0.395), trilogy contentious (0.392), wars rise (0.388), standout performances (0.375), criticized detracting (0.355), particularly praised (0.354), adam driver (0.352), coherent narrative (0.348), criticize (0.344), closure saga (0.343), characters felt (0.334), popping visuals (0.328), depth plot (0.324), standout aspect (0.318), story develop (0.317), service nostalgia (0.317), heightened return (0.317), experience action (0.316), effects enhance (0.306), highly praised (0.302), overall opinions (0.290), saga receives (0.281), praise nostalgic (0.236), plot inconsistencies (0.236), treat eyes (0.219)

# %% [markdown]
# ## Integration of AI-Extracted Keywords into the Existing Ground Truth Dataset

# %% [markdown]
# This cell performs the integration of newly extracted keywords from AI-generated film review summaries into the pre-existing keyword dataset (`keywords_ground_truth.pkl`).
#
# The process includes the following steps:
#
# 1. **Loading and Mapping:** The existing dataset is loaded, and a mapping from film titles to unique movie identifiers (`Movie_ID`) is defined to ensure accurate association of keywords with their respective films.
#
# 2. **Keyword Consolidation:** For each film in the extracted keywords dictionary, the code consolidates the highest relevance scores for each keyword across all thematic categories.
#
# 3. **Filtering:** Non-informative phrases such as `"reviewers say"` are removed explicitly. Additionally, any keywords already present in the existing dataset for that film are identified and excluded from insertion to prevent duplicates.
#
# 4. **Ranking and Voting:** Remaining new keywords are sorted in descending order by relevance score. Helpful vote counts are assigned incrementally starting just above the maximum existing vote count for the film, ensuring that the most relevant keywords receive the highest votes.
#
# 5. **Dataframe Construction:** A new dataframe is created for the filtered keywords, including their associated `Movie_ID`, keyword text, and assigned helpful and not helpful vote counts.
#
# 6. **Dataset Update:** The new keywords dataframe is concatenated on top of the existing dataset, and the updated dataset is saved back to the original file path.
#
# This workflow enhances the ground truth keyword dataset by enriching it with relevant audience-derived descriptors while maintaining data consistency and quality.

# %%
# Load the existing dataset
df_existing = pd.read_pickle("../Dataset/keywords_ground_truth.pkl")

# Map film titles to Movie_IDs (replace with your actual mapping)
movie_id_map = {
    "Parasite": "tt6751668",
    "Raiders of the Lost Ark": "tt0082971",
    "Oppenheimer": "tt15398776",
    "Harry Potter and the Sorcerer's Stone": "tt0241527",
    "The Good, the Bad and the Ugly": "tt0060196",
    "Star Wars Episode 3": "tt0121766",
    "Star Wars Episode 4": "tt0076759",
    "Star Wars Episode 5": "tt0080684",
    "Star Wars Episode 6": "tt0086190",
    "Star Wars Episode 7": "tt2488496",
    "Star Wars Episode 8": "tt2527336",
    "Star Wars Episode 9": "tt2527338",
}

dfs_to_prepend = []

for film, themes in extracted_keywords.items():
    if film not in movie_id_map:
        print(f"Warning: Movie_ID not found for film '{film}'. Skipping.")
        continue
    movie_id = movie_id_map[film]

    # Check if Movie_ID actually exists in the existing dataset
    if movie_id not in df_existing["Movie_ID"].values:
        print(f"Error: Movie_ID '{movie_id}' for film '{film}' not found in existing dataset. Skipping.")
        continue

    # Collect max score per keyword across all themes
    keyword_max_scores = {}
    for keywords in themes.values():
        for kw, score in keywords:
            if kw not in keyword_max_scores or score > keyword_max_scores[kw]:
                keyword_max_scores[kw] = score

    # Remove the keyword "reviewers say" if present (case insensitive)
    to_remove_reviewers_say = [kw for kw in keyword_max_scores if kw.lower() == "reviewers say"]
    if to_remove_reviewers_say:
        print(f"Removing 'reviewers say' keyword for '{film}'")
    for kw in to_remove_reviewers_say:
        keyword_max_scores.pop(kw)

    # Get existing keywords for this movie (lowercase for case-insensitive matching)
    existing_keywords = set(
        df_existing[df_existing["Movie_ID"] == movie_id]["Keyword"].str.lower()
    )

    # Identify keywords to remove (already present)
    to_remove = [kw for kw in keyword_max_scores if kw.lower() in existing_keywords]
    if to_remove:
        print(f"Removing existing keywords for '{film}': {to_remove}")

    # Remove them from new keywords
    for kw in to_remove:
        keyword_max_scores.pop(kw)

    # Sort remaining new keywords by descending score
    sorted_new_kws = sorted(keyword_max_scores.items(), key=lambda x: x[1], reverse=True)

    # Find max Helpful vote currently existing for this movie, default 0 if none
    max_helpful_existing = df_existing[df_existing["Movie_ID"] == movie_id]["Helpful"].max()
    if pd.isna(max_helpful_existing):
        max_helpful_existing = 0

    # Assign Helpful votes starting from max_helpful_existing + len(new keywords) down to max_helpful_existing + 1
    # So the keyword with highest score gets highest Helpful vote
    helpful_votes = list(range(int(max_helpful_existing) + len(sorted_new_kws), int(max_helpful_existing), -1))

    # Create dataframe of new keywords with votes and movie ID
    df_new = pd.DataFrame({
        "Movie_ID": movie_id,
        "Keyword": [kw for kw, _ in sorted_new_kws],
        "Helpful": helpful_votes,
        "Not_Helpful": [0] * len(sorted_new_kws)
    })

    dfs_to_prepend.append(df_new)

# Concatenate new keywords on top of existing ones
df_new_keywords = pd.concat(dfs_to_prepend, ignore_index=True)
df_updated = pd.concat([df_new_keywords, df_existing], ignore_index=True)

# Save updated dataframe
df_updated.to_pickle("../Dataset/keywords_ground_truth.pkl")
print("Updated dataset saved as 'keywords_ground_truth.pkl'")
# Out:
# Removing 'reviewers say' keyword for 'Parasite'
# Removing existing keywords for 'Parasite': ['social commentary']
# Removing 'reviewers say' keyword for 'Oppenheimer'
# Removing existing keywords for 'Oppenheimer': ['manhattan project']
# Removing 'reviewers say' keyword for 'The Good, the Bad and the Ugly'
# Removing 'reviewers say' keyword for 'Harry Potter and the Sorcerer's Stone'
# Removing existing keywords for 'Star Wars Episode 3': ['star wars', 'jedi council']
# Removing existing keywords for 'Star Wars Episode 4': ['star wars', 'death star', 'alien']
# Removing existing keywords for 'Star Wars Episode 5': ['asteroid field']
# Removing existing keywords for 'Star Wars Episode 7': ['star wars']
# Removing 'reviewers say' keyword for 'Star Wars Episode 8'
# Removing existing keywords for 'Star Wars Episode 8': ['canto bight']
# Removing 'reviewers say' keyword for 'Star Wars Episode 9'
# Updated dataset saved as 'keywords_ground_truth.pkl'

# %% [markdown]
# ## Loading and Inspecting the Updated Keywords Dataset
#
# This cell loads the updated keyword dataset from the specified pickle file path (`keywords_ground_truth.pkl`) and provides an initial inspection.
#
# It displays the total number of keywords contained in the dataset, followed by a preview of the first few rows to illustrate the data structure.
#
# Additionally, it computes and prints the count of keywords associated with each movie, offering insight into the distribution of keyword data across the films in the dataset.

# %%
# File path
file_path = "../Dataset/keywords_ground_truth.pkl"

# Load data
with open(file_path, 'rb') as file:
    keywords_df = pickle.load(file)

# Total number of keywords
total_keywords = len(keywords_df)
print(f"Total number of keywords: {total_keywords}\n")

# Display the first few rows
display(keywords_df.head())

# Count number of keywords per movie
print("\nNumber of keywords per movie:")
keywords_per_movie = keywords_df.groupby("Movie_ID").size()
print(keywords_per_movie)
# Out:
# Total number of keywords: 6193
#     Movie_ID                      Keyword  Helpful  Not_Helpful
# 0  tt6751668  cinematography breathtaking       58            0
# 1  tt6751668                use symbolism       57            0
# 2  tt6751668              builds suspense       56            0
# 3  tt6751668              engaging climax       55            0
# 4  tt6751668                   dark humor       54            0
# Number of keywords per movie:
# Movie_ID
# tt0060196     322
# tt0076759     394
# tt0080684     345
# tt0082971     272
# tt0086190     272
# tt0120915     410
# tt0121765     386
# tt0121766     523
# tt0241527     449
# tt15398776    367
# tt2488496     562
# tt2527336     589
# tt2527338     651
# tt3783958     290
# tt6751668     361
# dtype: int64
