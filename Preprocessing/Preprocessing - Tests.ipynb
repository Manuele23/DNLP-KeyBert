# %% [markdown]
# ## Verifying Preprocessing Output
#
# To ensure that the preprocessing steps were applied correctly, we display a few samples from each dataset, comparing original and processed fields side by side.
#
# For each dataset:
# - `Review_Title` and `Review_Text` show the original input.
# - `Processed_Review_Title` and `Processed_Review_Text` show the cleaned and normalized versions after applying stemming and lemmatization, respectively.
#
# This visual inspection helps verify that:
# - Lowercasing and punctuation removal were applied correctly.
# - Lemmatization reduced words to their base forms in the main text.
#
# All columns are shown without truncation to allow for a complete inspection of both the original and processed text fields, along with any other metadata present in the dataset.

# %%
import pandas as pd

# %%
# Display settings for full visibility
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Load the preprocessed dataset
df_others = pd.read_pickle('../Dataset/preprocessed_others_reviews_df.pkl')

# Display a sample of 5 rows
display(df_others.sample(5, random_state=42))
# Out:
#      Review_ID    Movie_ID  Movie_Title  Rating       Review_Date  \
# 566    5477546   tt6751668     Parasite     5.0  12 February 2020
# 3457  10253669  tt15398776  Oppenheimer    10.0   11 January 2025
# 2444   9205296  tt15398776  Oppenheimer     7.0      21 July 2023
# 1263   9580891  tt15398776  Oppenheimer     4.0   23 January 2024
# 2012   5530258   tt6751668     Parasite     9.0      6 March 2020
#
#                                                   Review_Title  \
# 566   Am I the only one who thought this movie was lackluster?
# 3457                              Oppenheimer a splendid movie
# 2444                                     A good but long watch
# 1263               Another confused, bloated Nolan production.
# 2012                                            Masterpiece...
#
# ...

# %%
import pandas as pd

# Display settings for full visibility
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Load the preprocessed dataset
df_others = pd.read_pickle('../Dataset/preprocessed_sw_reviews_df.pkl')

# Display a sample of 5 rows
display(df_others.sample(5, random_state=42))
